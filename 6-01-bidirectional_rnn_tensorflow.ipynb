# %%
print("https://www.tensorflow.org/api_docs/python/tf/nn/static_bidirectional_rnn")
"""
static_bidirectional_rnn(
    cell_fw,
    cell_bw,
    inputs,
    initial_state_fw=None,
    initial_state_bw=None,
    dtype=None,
    sequence_length=None,
    scope=None
)

Returns:
 (outputs, output_state_fw, output_state_bw) 

outputs 連結結果
output_state_fw : フォワードrnnの最終状態
output_state_bw : 後方rnnの最終状態
"""
pass
# Out:
# https://www.tensorflow.org/api_docs/python/tf/nn/static_bidirectional_rnn

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.contrib import rnn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

np.random.seed(0)
tf.set_random_seed(1234)

def inference(x, n_in=None, n_time=None, n_hidden=None, n_out=None):
    def weight_variable(shape):
        initial = tf.truncated_normal(shape, stddev=0.01)
        return tf.Variable(initial)

    def bias_variable(shape):
        initial = tf.zeros(shape, dtype=tf.float32)
        return tf.Variable(initial)

    # 時系列データの形式をAPIの仕様に合わせるため、最終的に
    # (ミニバッチサイズ, 入力次元数) が時間長分ある形に変形
    x = tf.transpose(x, [1, 0, 2])
    x = tf.reshape(x, [-1, n_in])
    x = tf.split(x, n_time, 0)

    cell_forward = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    cell_backward = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)
    outputs, _, _ = rnn.static_bidirectional_rnn(cell_forward, cell_backward,
                                                 x, dtype=tf.float32)

    W = weight_variable([n_hidden * 2, n_out])
    b = bias_variable([n_out])
    y = tf.nn.softmax(tf.matmul(outputs[-1], W) + b)
    return y

def loss(y, t):
    cross_entropy = \
        tf.reduce_mean(-tf.reduce_sum(
                       t * tf.log(tf.clip_by_value(y, 1e-10, 1.0)),
                       reduction_indices=[1]))
    return cross_entropy

def training(loss):
    optimizer = \
        tf.train.AdamOptimizer(learning_rate=0.001, beta1=0.9, beta2=0.999)
    train_step = optimizer.minimize(loss)
    return train_step

def accuracy(y, t):
    correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(t, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    return accuracy

class EarlyStopping():
    def __init__(self, patience=0, verbose=0):
        self._step = 0
        self._loss = float('inf')
        self.patience = patience
        self.verbose = verbose

    def validate(self, loss):
        if self._loss < loss:
            self._step += 1
            if self._step > self.patience:
                if self.verbose:
                    print('early stopping')
                return True
        else:
            self._step = 0
            self._loss = loss
        return False


if __name__ == '__main__':
    '''
    データの生成
    '''
    mnist = datasets.fetch_mldata('MNIST original', data_home='.')

    n = len(mnist.data)
    N = 30000  # MNISTの一部を使う
    N_train = 20000
    N_validation = 4000
    indices = np.random.permutation(range(n))[:N]  # ランダムにN枚を選択

    X = mnist.data[indices]
    X = X / 255.0
    X = X - X.mean(axis=1).reshape(len(X), 1)
    X = X.reshape(len(X), 28, 28)  # 時系列データに変換
    y = mnist.target[indices]
    Y = np.eye(10)[y.astype(int)]  # 1-of-K 表現に変換

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=N_train)
    X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=N_validation)

    '''
    モデル設定
    '''
    n_in = 28
    n_time = 28
    n_hidden = 128
    n_out = 10
    x = tf.placeholder(tf.float32, shape=[None, n_time, n_in])
    t = tf.placeholder(tf.float32, shape=[None, n_out])
    y = inference(x, n_in=n_in, n_time=n_time, n_hidden=n_hidden, n_out=n_out)
    loss = loss(y, t)
    train_step = training(loss)

    accuracy = accuracy(y, t)
    early_stopping = EarlyStopping(patience=10, verbose=1)
    history = {
        'val_loss': [],
        'val_acc': []
    }

    '''
    モデル学習
    '''
    epochs = 300
    batch_size = 250
    init = tf.global_variables_initializer()
    sess = tf.Session()
    sess.run(init)

    n_batches = N_train // batch_size

    for epoch in range(epochs):
        X_, Y_ = shuffle(X_train, Y_train)
        for i in range(n_batches):
            start = i * batch_size
            end = start + batch_size

            sess.run(train_step, feed_dict={
                x: X_[start:end],
                t: Y_[start:end]
            })

        val_loss = loss.eval(session=sess, feed_dict={
            x: X_validation,
            t: Y_validation
        })
        val_acc = accuracy.eval(session=sess, feed_dict={
            x: X_validation,
            t: Y_validation
        })

        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        print('epoch:', epoch,
              ' validation loss:', val_loss,
              ' validation accuracy:', val_acc)

        if early_stopping.validate(val_loss):
            break

    '''
    学習の進み具合を可視化
    '''
    loss = history['val_loss']

    plt.rc('font', family='serif')
    fig = plt.figure()
    plt.plot(range(len(loss)), loss,
             label='loss', color='black')
    plt.xlabel('epochs')
    plt.show()

    '''
    予測精度の評価
    '''
    accuracy_rate = accuracy.eval(session=sess, feed_dict={
        x: X_test,
        t: Y_test
    })
    print('accuracy: ', accuracy_rate)
# Out:
# epoch: 0  validation loss: 1.38903  validation accuracy: 0.5495
# epoch: 1  validation loss: 1.26558  validation accuracy: 0.58225
# epoch: 2  validation loss: 0.788498  validation accuracy: 0.74525
# epoch: 3  validation loss: 0.818152  validation accuracy: 0.74375
# epoch: 4  validation loss: 0.956571  validation accuracy: 0.70225
# epoch: 5  validation loss: 0.407708  validation accuracy: 0.86725
# epoch: 6  validation loss: 0.378204  validation accuracy: 0.87325
# epoch: 7  validation loss: 0.312203  validation accuracy: 0.90325
# epoch: 8  validation loss: 0.383711  validation accuracy: 0.8795
# epoch: 9  validation loss: 0.663791  validation accuracy: 0.78375
# epoch: 10  validation loss: 0.243148  validation accuracy: 0.92325
# epoch: 11  validation loss: 0.274138  validation accuracy: 0.9205
# epoch: 12  validation loss: 0.213661  validation accuracy: 0.93825
# epoch: 13  validation loss: 0.232305  validation accuracy: 0.93
# epoch: 14  validation loss: 0.226855  validation accuracy: 0.92975
# epoch: 15  validation loss: 0.173697  validation accuracy: 0.951
# epoch: 16  validation loss: 0.254788  validation accuracy: 0.9325
# epoch: 17  validation loss: 0.138602  validation accuracy: 0.9575
# epoch: 18  validation loss: 0.179899  validation accuracy: 0.94775
# epoch: 19  validation loss: 0.171027  validation accuracy: 0.949
# epoch: 20  validation loss: 0.200455  validation accuracy: 0.94025
# epoch: 21  validation loss: 0.138235  validation accuracy: 0.95975
# epoch: 22  validation loss: 0.388375  validation accuracy: 0.887
# epoch: 23  validation loss: 0.146006  validation accuracy: 0.959
# epoch: 24  validation loss: 0.145672  validation accuracy: 0.9555
# epoch: 25  validation loss: 0.256487  validation accuracy: 0.9235
# epoch: 26  validation loss: 0.115895  validation accuracy: 0.968
# epoch: 27  validation loss: 0.205711  validation accuracy: 0.94225
# epoch: 28  validation loss: 0.110403  validation accuracy: 0.9695
# epoch: 29  validation loss: 0.124111  validation accuracy: 0.96725
# epoch: 30  validation loss: 0.179522  validation accuracy: 0.95275
# epoch: 31  validation loss: 0.182931  validation accuracy: 0.9525
# epoch: 32  validation loss: 0.149846  validation accuracy: 0.9565
# epoch: 33  validation loss: 0.112707  validation accuracy: 0.96975
# epoch: 34  validation loss: 0.135997  validation accuracy: 0.9655
# epoch: 35  validation loss: 0.10914  validation accuracy: 0.97075
# epoch: 36  validation loss: 0.104804  validation accuracy: 0.97675
# epoch: 37  validation loss: 0.10145  validation accuracy: 0.97625
# epoch: 38  validation loss: 0.137069  validation accuracy: 0.96625
# epoch: 39  validation loss: 0.188276  validation accuracy: 0.94825
# epoch: 40  validation loss: 0.155033  validation accuracy: 0.96275
# epoch: 41  validation loss: 0.202108  validation accuracy: 0.94975
# epoch: 42  validation loss: 0.197989  validation accuracy: 0.94875
# epoch: 43  validation loss: 0.14088  validation accuracy: 0.96425
# epoch: 44  validation loss: 0.113946  validation accuracy: 0.9705
# epoch: 45  validation loss: 0.0965317  validation accuracy: 0.975
# epoch: 46  validation loss: 0.116987  validation accuracy: 0.97125
# epoch: 47  validation loss: 0.0929192  validation accuracy: 0.9795
# epoch: 48  validation loss: 0.0932806  validation accuracy: 0.979
# epoch: 49  validation loss: 0.0987351  validation accuracy: 0.9785
# epoch: 50  validation loss: 0.102076  validation accuracy: 0.97775
# epoch: 51  validation loss: 0.0979447  validation accuracy: 0.98025
# epoch: 52  validation loss: 0.100815  validation accuracy: 0.98025
# epoch: 53  validation loss: 0.102727  validation accuracy: 0.97975
# epoch: 54  validation loss: 0.0991602  validation accuracy: 0.9805
# epoch: 55  validation loss: 0.102461  validation accuracy: 0.98
# epoch: 56  validation loss: 0.101213  validation accuracy: 0.9805
# epoch: 57  validation loss: 0.103786  validation accuracy: 0.98
# epoch: 58  validation loss: 0.103245  validation accuracy: 0.97925
# early stopping
# accuracy:  0.9768
